# %% [markdown]
# # Resource Consumption Results
#
# This notebook contains the visualization of the resource consumption in terms time and memory used for the different search strategies (Best First Search, Threshold Based, Limited Level Width BFS) and algorithms (Path Message Patching, Path Attribution Patching, Path Message Patching with Batching over Poisitions and/or Heads) implemented in the IPE framework.
# In all experiments, we have tackled the Indirect Object Identification (IOI) task using a single batch of 8 examples and zero ablation (so no counterfactual was used). The metric used was the target logit percentage, i.e., the percentage of the original target logit that is recovered after zero ablating a path, nonetheless different metrics does not particularly effect the results.
# Note that the reported times and memory consumptions also include the overhead due the initial forward pass and caching of all the clean activations.
#
# All experiments have been conducted on a machine with the following specifications:
#
#     processor:      13th Gen Intel(R) Core(TM) i9-13900K
#     RAM:            64GiB System memory
#     GPU:            GeForce RTX 4090
#     OS:             Ubuntu 24.04.1 LTS
#     Python:         3.12.3
#
# To also evaluate in a straightforward way the quality of the indentified paths, we report the number of paths whose exact contribution is over a certain threshold, chosen to be 0.5% of the recovered target logit.

# %% [markdown]
# ## GPT2

# %% [markdown]
# ### GPT2: Positional Search

# %%
import pandas as pd
from IPython.display import display

filepath = "./results/gpt2/ioi_positional_bs8_len15.csv" # Example file, to be tested more

df = pd.read_csv(filepath)
display(df)
# Out:
#                                   type    search_strategy   top_n  threshold  \
# 0              PathAttributionPatching    BestFirstSearch    10.0        NaN
# 1              PathAttributionPatching    BestFirstSearch   100.0        NaN
# 2              PathAttributionPatching    BestFirstSearch  1000.0        NaN
# 3              PathAttributionPatching          Threshold     NaN       1.00
# 4              PathAttributionPatching          Threshold     NaN       0.50
# 5              PathAttributionPatching          Threshold     NaN       0.25
# 6              PathAttributionPatching  LimitedLevelWidth     NaN        NaN
# 7              PathAttributionPatching  LimitedLevelWidth     NaN        NaN
# 8              PathAttributionPatching  LimitedLevelWidth     NaN        NaN
# 9                  PathMessagePatching    BestFirstSearch    10.0        NaN
# 10                 PathMessagePatching    BestFirstSearch   100.0        NaN
# 11                 PathMessagePatching    BestFirstSearch  1000.0        NaN
# 12                 PathMessagePatching          Threshold     NaN       1.00
# 13                 PathMessagePatching          Threshold     NaN       0.50
# 14                 PathMessagePatching          Threshold     NaN       0.25
# 15                 PathMessagePatching  LimitedLevelWidth     NaN        NaN
# 16                 PathMessagePatching  LimitedLevelWidth     NaN        NaN
# 17                 PathMessagePatching  LimitedLevelWidth     NaN        NaN
# 18  PathMessagePatchingBatchedHeadsPos    BestFirstSearch    10.0        NaN
# 19  PathMessagePatchingBatchedHeadsPos    BestFirstSearch   100.0        NaN
# 20  PathMessagePatchingBatchedHeadsPos    BestFirstSearch  1000.0        NaN
# 21  PathMessagePatchingBatchedHeadsPos          Threshold     NaN       1.00
# 22  PathMessagePatchingBatchedHeadsPos          Threshold     NaN       0.50
# 23  PathMessagePatchingBatchedHeadsPos          Threshold     NaN       0.25
# 24  PathMessagePatchingBatchedHeadsPos  LimitedLevelWidth     NaN        NaN
# 25  PathMessagePatchingBatchedHeadsPos  LimitedLevelWidth     NaN        NaN
# 26  PathMessagePatchingBatchedHeadsPos  LimitedLevelWidth     NaN        NaN
# 27       PathMessagePatchingBatchedPos    BestFirstSearch    10.0        NaN
# 28       PathMessagePatchingBatchedPos    BestFirstSearch   100.0        NaN
# 29       PathMessagePatchingBatchedPos    BestFirstSearch  1000.0        NaN
# 30       PathMessagePatchingBatchedPos          Threshold     NaN       1.00
# 31       PathMessagePatchingBatchedPos          Threshold     NaN       0.50
# 32       PathMessagePatchingBatchedPos          Threshold     NaN       0.25
# 33       PathMessagePatchingBatchedPos  LimitedLevelWidth     NaN        NaN
# 34       PathMessagePatchingBatchedPos  LimitedLevelWidth     NaN        NaN
# 35       PathMessagePatchingBatchedPos  LimitedLevelWidth     NaN        NaN
#
#     max_width  paths_found  relevant_paths_found  execution_time_s  \
# 0         NaN           10                     8            2.2979
# 1         NaN          100                    82            6.6630
# 2         NaN         1000                   312           31.9521
# 3         NaN          773                    91            6.8582
# 4         NaN         4356                   282           25.2366
# 5         NaN        31588                   505          141.7298
# 6        10.0           81                     4            2.2035
# 7       100.0         1101                    56            8.4161
# 8      1000.0        12001                   268           64.2976
# 9         NaN           10                    10          237.2900
# 10        NaN          100                   100          758.7578
# 11        NaN         1000                   492         3296.8329
# 12        NaN          752                    87          395.3635
# 13        NaN         4280                   343         1600.5827
# 14        NaN        29258                   609         7377.8796
# 15       10.0           91                     5           33.0491
# 16      100.0         1101                    71          255.2948
# 17     1000.0        12001                   325         2040.0908
# 18        NaN           10                    10           26.9790
# 19        NaN          100                   100           90.5984
# 20        NaN         1000                   466          547.3577
# 21        NaN          485                    78           14.1582
# 22        NaN         2488                   287           64.9283
# 23        NaN        15326                   530          360.9965
# 24       10.0           61                     6            4.7112
# 25      100.0         1101                    83           74.4873
# 26     1000.0        11001                   369          556.1005
# 27        NaN           10                    10           27.5892
# 28        NaN          100                   100          119.3816
# 29        NaN         1000                   666          714.2166
# 30        NaN          735                    87           72.1191
# 31        NaN         4123                   326          324.9559
# 32        NaN        28149                   594         1675.2555
# 33       10.0           61                     6            6.3834
# 34      100.0         1001                    71           51.8483
# 35     1000.0        12001                   281          498.2006
#
#     peak_process_memory_mb
# 0                   2408.0
# 1                   2408.0
# 2                   2408.0
# 3                   2408.0
# 4                   2452.0
# 5                   2508.0
# 6                   2436.0
# 7                   2446.0
# 8                   2472.0
# 9                   2262.0
# 10                  2262.0
# 11                  2262.0
# 12                  2262.0
# 13                  2262.0
# 14                  2262.0
# 15                  2262.0
# 16                  2262.0
# 17                  2262.0
# 18                  2060.0
# 19                  2194.0
# 20                  2262.0
# 21                  1642.0
# 22                  1888.0
# 23                  2176.0
# 24                  1806.0
# 25                  2262.0
# 26                  2262.0
# 27                  1398.0
# 28                  1398.0
# 29                  1398.0
# 30                  1692.0
# 31                  1930.0
# 32                  2196.0
# 33                  1452.0
# 34                  1720.0
# 35                  2262.0

# %%
from plot import plot_search_strategy_results

# Example 1: Plot vs. Execution Time (default) with labels
plot_search_strategy_results(
    df.copy(),
    x_axis_col='execution_time_s',
    show_labels=False,
    save_path="plot_vs_time_with_labels.png",
    model="gpt2-small",
)

# Example 2: Plot vs. Memory Consumption, without labels
plot_search_strategy_results(
    df.copy(),
    x_axis_col='peak_process_memory_mb',
    show_labels=False,
    save_path="plot_vs_memory_no_labels.png",
    model="gpt2-small",
)

# %% [markdown]
# ### GPT2: Non-Positional Search

# %%
import pandas as pd
from IPython.display import display

filepath = "./results/gpt2/ioi_non_positional_bs8_len15.csv" # Example file, to be tested more

df = pd.read_csv(filepath)
display(df)
# Out:
#                                   type    search_strategy   top_n  threshold  \
# 0              PathAttributionPatching    BestFirstSearch    10.0        NaN
# 1              PathAttributionPatching    BestFirstSearch   100.0        NaN
# 2              PathAttributionPatching    BestFirstSearch  1000.0        NaN
# 3              PathAttributionPatching          Threshold     NaN       1.00
# 4              PathAttributionPatching          Threshold     NaN       0.50
# 5              PathAttributionPatching          Threshold     NaN       0.25
# 6              PathAttributionPatching  LimitedLevelWidth     NaN        NaN
# 7              PathAttributionPatching  LimitedLevelWidth     NaN        NaN
# 8              PathAttributionPatching  LimitedLevelWidth     NaN        NaN
# 9                  PathMessagePatching    BestFirstSearch    10.0        NaN
# 10                 PathMessagePatching    BestFirstSearch   100.0        NaN
# 11                 PathMessagePatching    BestFirstSearch  1000.0        NaN
# 12                 PathMessagePatching          Threshold     NaN       1.00
# 13                 PathMessagePatching          Threshold     NaN       0.50
# 14                 PathMessagePatching          Threshold     NaN       0.25
# 15                 PathMessagePatching  LimitedLevelWidth     NaN        NaN
# 16                 PathMessagePatching  LimitedLevelWidth     NaN        NaN
# 17                 PathMessagePatching  LimitedLevelWidth     NaN        NaN
# 18  PathMessagePatchingBatchedHeadsPos    BestFirstSearch    10.0        NaN
# 19  PathMessagePatchingBatchedHeadsPos    BestFirstSearch   100.0        NaN
# 20  PathMessagePatchingBatchedHeadsPos    BestFirstSearch  1000.0        NaN
# 21  PathMessagePatchingBatchedHeadsPos          Threshold     NaN       1.00
# 22  PathMessagePatchingBatchedHeadsPos          Threshold     NaN       0.50
# 23  PathMessagePatchingBatchedHeadsPos          Threshold     NaN       0.25
# 24  PathMessagePatchingBatchedHeadsPos  LimitedLevelWidth     NaN        NaN
# 25  PathMessagePatchingBatchedHeadsPos  LimitedLevelWidth     NaN        NaN
# 26  PathMessagePatchingBatchedHeadsPos  LimitedLevelWidth     NaN        NaN
#
#     max_width  paths_found  relevant_paths_found  execution_time_s  \
# 0         NaN           10                    10            0.5359
# 1         NaN          100                    95            3.1742
# 2         NaN         1000                   492           25.1909
# 3         NaN          975                   114            3.4454
# 4         NaN         6246                   341           17.9220
# 5         NaN        47306                   891          130.3830
# 6        10.0           81                    11            1.1439
# 7       100.0         1101                    81            4.9482
# 8      1000.0        10733                   311           37.6927
# 9         NaN           10                    10           25.3842
# 10        NaN          100                   100          110.4848
# 11        NaN         1000                   666          666.1899
# 12        NaN          985                   122           78.6727
# 13        NaN         6123                   444          386.7725
# 14        NaN        44494                  1075         2090.9057
# 15       10.0           81                    10            4.6252
# 16      100.0         1001                    85           48.4965
# 17     1000.0        10781                   395          394.3337
# 18        NaN           10                    10            4.1227
# 19        NaN          100                   100           18.3425
# 20        NaN         1000                   584          156.2849
# 21        NaN          632                   103           15.4111
# 22        NaN         3187                   347           61.9542
# 23        NaN        21985                   864          359.1121
# 24       10.0           61                     4            1.0857
# 25      100.0         1101                   101           19.0609
# 26     1000.0        10565                   443          175.3214
#
#     peak_process_memory_mb
# 0                   1530.0
# 1                   1658.0
# 2                   2778.0
# 3                   1592.0
# 4                   1926.0
# 5                   3806.0
# 6                   1474.0
# 7                   1614.0
# 8                   2334.0
# 9                   1398.0
# 10                  1398.0
# 11                  1398.0
# 12                  1398.0
# 13                  1398.0
# 14                  1412.0
# 15                  1398.0
# 16                  1398.0
# 17                  1398.0
# 18                  1390.0
# 19                  1398.0
# 20                  1398.0
# 21                  1398.0
# 22                  1398.0
# 23                  1400.0
# 24                  1386.0
# 25                  1398.0
# 26                  1398.0

# %%
from plot import plot_search_strategy_results

# Example 1: Plot vs. Execution Time (default) with labels
plot_search_strategy_results(
    df.copy(),
    x_axis_col='execution_time_s',
    show_labels=False,
    save_path="plot_vs_time_with_labels.png",
    model="gpt2-small",
)

# Example 2: Plot vs. Memory Consumption, without labels
plot_search_strategy_results(
    df.copy(),
    x_axis_col='peak_process_memory_mb',
    show_labels=False,
    save_path="plot_vs_memory_no_labels.png",
    model="gpt2-small",
)

# %% [markdown]
# ## Qwen2.5 - 0.5B

# %% [markdown]
# ### Qwen2.5 - 0.5B: Positional Search

# %%
import pandas as pd
from IPython.display import display

filepath = "./results/qwen/ioi_positional_bs8_len15.csv"

df = pd.read_csv(filepath)
display(df)
# Out:
#                                   type    search_strategy   top_n  threshold  \
# 0              PathAttributionPatching    BestFirstSearch   100.0        NaN
# 1              PathAttributionPatching          Threshold     NaN        1.0
# 2              PathAttributionPatching          Threshold     NaN        0.5
# 3              PathAttributionPatching  LimitedLevelWidth     NaN        NaN
# 4                  PathMessagePatching    BestFirstSearch   100.0        NaN
# 5                  PathMessagePatching          Threshold     NaN        2.0
# 6                  PathMessagePatching          Threshold     NaN        1.0
# 7                  PathMessagePatching          Threshold     NaN        0.5
# 8                  PathMessagePatching  LimitedLevelWidth     NaN        NaN
# 9   PathMessagePatchingBatchedHeadsPos    BestFirstSearch   100.0        NaN
# 10  PathMessagePatchingBatchedHeadsPos          Threshold     NaN        1.0
# 11  PathMessagePatchingBatchedHeadsPos          Threshold     NaN        0.5
# 12  PathMessagePatchingBatchedHeadsPos  LimitedLevelWidth     NaN        NaN
# 13       PathMessagePatchingBatchedPos    BestFirstSearch   100.0        NaN
# 14       PathMessagePatchingBatchedPos          Threshold     NaN        1.0
# 15       PathMessagePatchingBatchedPos          Threshold     NaN        0.5
# 16       PathMessagePatchingBatchedPos  LimitedLevelWidth     NaN        NaN
# 17             PathAttributionPatching    BestFirstSearch    10.0        NaN
# 18             PathAttributionPatching    BestFirstSearch  1000.0        NaN
# 19             PathAttributionPatching          Threshold     NaN        1.5
# 20             PathAttributionPatching  LimitedLevelWidth     NaN        NaN
# 21             PathAttributionPatching  LimitedLevelWidth     NaN        NaN
# 22                 PathMessagePatching    BestFirstSearch    10.0        NaN
# 23                 PathMessagePatching    BestFirstSearch  1000.0        NaN
# 24                 PathMessagePatching          Threshold     NaN        1.5
# 25                 PathMessagePatching  LimitedLevelWidth     NaN        NaN
# 26                 PathMessagePatching  LimitedLevelWidth     NaN        NaN
# 27  PathMessagePatchingBatchedHeadsPos    BestFirstSearch    10.0        NaN
# 28  PathMessagePatchingBatchedHeadsPos    BestFirstSearch  1000.0        NaN
# 29  PathMessagePatchingBatchedHeadsPos          Threshold     NaN        1.5
# 30  PathMessagePatchingBatchedHeadsPos  LimitedLevelWidth     NaN        NaN
# 31  PathMessagePatchingBatchedHeadsPos  LimitedLevelWidth     NaN        NaN
# 32       PathMessagePatchingBatchedPos    BestFirstSearch    10.0        NaN
# 33       PathMessagePatchingBatchedPos    BestFirstSearch  1000.0        NaN
# 34       PathMessagePatchingBatchedPos          Threshold     NaN        1.5
# 35       PathMessagePatchingBatchedPos  LimitedLevelWidth     NaN        NaN
# 36       PathMessagePatchingBatchedPos  LimitedLevelWidth     NaN        NaN
#
#     max_width  paths_found  relevant_paths_found  execution_time_s  \
# 0         NaN          100                    70          101.7599
# 1         NaN          824                   174           13.1093
# 2         NaN         4353                   367           60.0084
# 3        10.0          101                     1            5.5921
# 4         NaN          100                   100          175.3843
# 5         NaN           55                     1          154.0908
# 6         NaN         1948                   729          692.4992
# 7         NaN         7335                  1559         6493.2559
# 8        10.0          171                     1          332.0659
# 9         NaN          100                   100           13.4302
# 10        NaN         1658                   649           22.8602
# 11        NaN         4539                  1248           96.3443
# 12       10.0          161                     0           32.1745
# 13        NaN          100                   100          607.1556
# 14        NaN         1944                   729          136.9155
# 15        NaN         7319                  1558         1030.6507
# 16       10.0           81                    21           16.1250
# 17        NaN           10                    10            6.7757
# 18        NaN         1000                   255          529.8757
# 19        NaN          222                    45            6.9833
# 20      100.0          843                   133           15.8267
# 21     1000.0        19001                   489          199.1602
# 22        NaN           10                    10          162.9952
# 23        NaN         1000                  1000         1932.9822
# 24        NaN          892                   350          278.1132
# 25      100.0          901                   226          769.7976
# 26     1000.0        15001                  1574         9309.1951
# 27        NaN           10                    10            9.0350
# 28        NaN         1000                  1000          106.3407
# 29        NaN          508                   186            8.6161
# 30      100.0          901                   226           52.9266
# 31     1000.0        17001                  1460         1817.1773
# 32        NaN           10                    10          100.8687
# 33        NaN         1000                   640         4451.7140
# 34        NaN          890                   350           65.2718
# 35      100.0          901                   222          127.5521
# 36     1000.0        17449                  1544         1776.7655
#
#     peak_process_memory_mb
# 0                   6390.0
# 1                   6390.0
# 2                   6390.0
# 3                   6390.0
# 4                   6224.0
# 5                   6224.0
# 6                   6224.0
# 7                   6224.0
# 8                   6224.0
# 9                   4474.0
# 10                  3878.0
# 11                  4420.0
# 12                  5152.0
# 13                  3704.0
# 14                  4092.0
# 15                  4560.0
# 16                  3752.0
# 17                  6390.0
# 18                  6390.0
# 19                  6390.0
# 20                  6502.0
# 21                  6610.0
# 22                  6224.0
# 23                  6224.0
# 24                  6224.0
# 25                  6224.0
# 26                  6224.0
# 27                  4344.0
# 28                  6112.0
# 29                  3776.0
# 30                  6224.0
# 31                  6224.0
# 32                  3704.0
# 33                  3704.0
# 34                  3906.0
# 35                  4146.0
# 36                  6224.0

# %%
from plot import plot_search_strategy_results

# Example 1: Plot vs. Execution Time (default) with labels
plot_search_strategy_results(
    df.copy(),
    x_axis_col='execution_time_s',
    show_labels=False,
    save_path="plot_vs_time_with_labels.png",
    model="Qwen2.5-0.5B",
)

# Example 2: Plot vs. Memory Consumption, without labels
plot_search_strategy_results(
    df.copy(),
    x_axis_col='peak_process_memory_mb',
    show_labels=False,
    save_path="plot_vs_memory_no_labels.png",
    model="Qwen2.5-0.5B",
)

# %% [markdown]
# ### Qwen2.5 - 0.5B: Non-Positional Search

# %%
import pandas as pd
from IPython.display import display

filepath = "./results/qwen/ioi_non_positional_bs8_len15.csv"

df = pd.read_csv(filepath)
display(df)
# Out:
#                                   type    search_strategy   top_n  threshold  \
# 0              PathAttributionPatching    BestFirstSearch   100.0        NaN
# 1              PathAttributionPatching          Threshold     NaN        1.0
# 2              PathAttributionPatching          Threshold     NaN        0.5
# 3              PathAttributionPatching  LimitedLevelWidth     NaN        NaN
# 4                  PathMessagePatching    BestFirstSearch   100.0        NaN
# 5                  PathMessagePatching          Threshold     NaN        1.0
# 6                  PathMessagePatching          Threshold     NaN        0.5
# 7                  PathMessagePatching  LimitedLevelWidth     NaN        NaN
# 8   PathMessagePatchingBatchedHeadsPos    BestFirstSearch   100.0        NaN
# 9   PathMessagePatchingBatchedHeadsPos          Threshold     NaN        1.0
# 10  PathMessagePatchingBatchedHeadsPos          Threshold     NaN        0.5
# 11  PathMessagePatchingBatchedHeadsPos  LimitedLevelWidth     NaN        NaN
# 12             PathAttributionPatching    BestFirstSearch    10.0        NaN
# 13             PathAttributionPatching    BestFirstSearch  1000.0        NaN
# 14             PathAttributionPatching          Threshold     NaN        1.5
# 15             PathAttributionPatching  LimitedLevelWidth     NaN        NaN
# 16             PathAttributionPatching  LimitedLevelWidth     NaN        NaN
# 17                 PathMessagePatching    BestFirstSearch    10.0        NaN
# 18                 PathMessagePatching    BestFirstSearch  1000.0        NaN
# 19                 PathMessagePatching          Threshold     NaN        1.5
# 20                 PathMessagePatching  LimitedLevelWidth     NaN        NaN
# 21                 PathMessagePatching  LimitedLevelWidth     NaN        NaN
# 22  PathMessagePatchingBatchedHeadsPos    BestFirstSearch    10.0        NaN
# 23  PathMessagePatchingBatchedHeadsPos    BestFirstSearch  1000.0        NaN
# 24  PathMessagePatchingBatchedHeadsPos          Threshold     NaN        1.5
# 25  PathMessagePatchingBatchedHeadsPos  LimitedLevelWidth     NaN        NaN
# 26  PathMessagePatchingBatchedHeadsPos  LimitedLevelWidth     NaN        NaN
#
#     max_width  paths_found  relevant_paths_found  execution_time_s  \
# 0         NaN          100                    35           20.9242
# 1         NaN         1180                   124            5.7768
# 2         NaN         6110                   282           25.3367
# 3        10.0           81                     1            1.4598
# 4         NaN          100                   100          589.4193
# 5         NaN          342                    11          109.3369
# 6         NaN         5185                   231         1264.9780
# 7        10.0           81                     3           18.8747
# 8         NaN          100                   100           43.0331
# 9         NaN          199                    11            9.8850
# 10        NaN         2350                   205           68.8218
# 11       10.0          161                     0            9.1218
# 12        NaN           10                     5            0.9576
# 13        NaN         1000                   219          192.1701
# 14        NaN          421                    53            2.7901
# 15      100.0         1001                   116            5.3924
# 16     1000.0        17697                   382           82.7721
# 17        NaN           10                    10           96.1628
# 18        NaN         1000                   640         4454.7405
# 19        NaN          111                     1           42.0646
# 20      100.0         1901                    28          289.2134
# 21     1000.0        18341                   392         2160.1014
# 22        NaN           10                    10            8.0332
# 23        NaN         1000                   616          329.3060
# 24        NaN           87                     1            4.5001
# 25      100.0         1401                    42           37.7853
# 26     1000.0        18893                   466          542.4058
#
#     peak_process_memory_mb
# 0                   4554.0
# 1                   3904.0
# 2                   4120.0
# 3                   3860.0
# 4                   3704.0
# 5                   3704.0
# 6                   3704.0
# 7                   3704.0
# 8                   3698.0
# 9                   3648.0
# 10                  3704.0
# 11                  3642.0
# 12                  3844.0
# 13                 10626.0
# 14                  3840.0
# 15                  3920.0
# 16                  4962.0
# 17                  3704.0
# 18                  3704.0
# 19                  3704.0
# 20                  3704.0
# 21                  3704.0
# 22                  3654.0
# 23                  3704.0
# 24                  3628.0
# 25                  3704.0
# 26                  3704.0

# %%
from plot import plot_search_strategy_results

# Example 1: Plot vs. Execution Time (default) with labels
plot_search_strategy_results(
    df.copy(),
    x_axis_col='execution_time_s',
    show_labels=False,
    save_path="plot_vs_time_with_labels.png",
    model="Qwen2.5-0.5B",
)

# Example 2: Plot vs. Memory Consumption, without labels
plot_search_strategy_results(
    df.copy(),
    x_axis_col='peak_process_memory_mb',
    show_labels=False,
    save_path="plot_vs_memory_no_labels.png",
    model="Qwen2.5-0.5B",
)
